# %%
import pandas as pd
# %matplotlib inline

# %%
broken_df = pd.read_csv('./data/comptagevelo2012.csv')

# %%
broken_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 11 columns):
# Date                           366 non-null object
# Unnamed: 1                     366 non-null object
# Rachel / Papineau              366 non-null int64
# Berri1                         366 non-null int64
# Maisonneuve_2                  366 non-null int64
# Maisonneuve_1                  366 non-null int64
# Brébeuf                        146 non-null float64
# Parc                           366 non-null int64
# PierDup                        366 non-null int64
# CSC (Côte Sainte-Catherine)    366 non-null int64
# Pont_Jacques_Cartier           317 non-null float64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 28.6+ KB

# %%
broken_df.describe()
# Out:
#        Rachel / Papineau       Berri1  Maisonneuve_2  Maisonneuve_1  \
# count         366.000000   366.000000     366.000000     366.000000
# mean         2605.653005  2678.234973    3172.120219    1783.762295
# std          2010.385246  2149.301945    2463.726403    1435.398169
# min             0.000000     4.000000       1.000000       4.000000
# 25%           441.500000   433.500000     604.000000     292.250000
# 50%          2458.500000  2326.000000    3044.000000    1702.000000
# 75%          4496.000000  4642.750000    5050.000000    2993.000000
# max          6595.000000  7104.000000    8220.000000    4999.000000
#
#            Brébeuf         Parc      PierDup  CSC (Côte Sainte-Catherine)  \
# count   146.000000   366.000000   366.000000                   366.000000
# mean    630.691781  1698.114754   907.019126                  1109.306011
# std     918.796008  1318.520253  1039.620662                   933.862044
# ...

# %%
broken_df.isnull().sum()
# Out:
# Date                             0
# Unnamed: 1                       0
# Rachel / Papineau                0
# Berri1                           0
# Maisonneuve_2                    0
# Maisonneuve_1                    0
# Brébeuf                        220
# Parc                             0
# PierDup                          0
# CSC (Côte Sainte-Catherine)      0
# Pont_Jacques_Cartier            49
# dtype: int64

# %%
broken_df[:3]
# Out:
#          Date Unnamed: 1  Rachel / Papineau  Berri1  Maisonneuve_2  \
# 0  01/01/2012      00:00                 16      35             51
# 1  02/01/2012      00:00                 43      83            153
# 2  03/01/2012      00:00                 58     135            248
#
#    Maisonneuve_1  Brébeuf  Parc  PierDup  CSC (Côte Sainte-Catherine)  \
# 0             38      5.0    26       10                            0
# 1             68     11.0    53        6                            1
# 2            104      2.0    89        3                            2
#
#    Pont_Jacques_Cartier
# 0                  27.0
# 1                  21.0
# 2                  15.0

# %%
fixed_df = pd.read_csv('./data/comptagevelo2012.csv', sep=',', encoding='latin1', parse_dates=['Date'], dayfirst=True, index_col='Date')

# %%
fixed_df['Berri1']
# Out:
# Date
# 2012-01-01      35
# 2012-01-02      83
# 2012-01-03     135
# 2012-01-04     144
# 2012-01-05     197
# 2012-01-06     146
# 2012-01-07      98
# 2012-01-08      95
# 2012-01-09     244
# 2012-01-10     397
# 2012-01-11     273
# 2012-01-12     157
# 2012-01-13      75
# 2012-01-14      32
# 2012-01-15      54
# 2012-01-16     168
# 2012-01-17     155
# 2012-01-18     139
# 2012-01-19     191
# 2012-01-20     161
# 2012-01-21      53
# 2012-01-22      71
# 2012-01-23     210
# 2012-01-24     299
# 2012-01-25     334
# 2012-01-26     306
# 2012-01-27      91
# 2012-01-28      80
# 2012-01-29      87
# 2012-01-30     219
#               ...
# 2012-12-02     324
# 2012-12-03    1286
# 2012-12-04    1264
# 2012-12-05    1204
# 2012-12-06    1252
# 2012-12-07    1151
# 2012-12-08     382
# 2012-12-09     427
# 2012-12-10     245
# 2012-12-11     517
# 2012-12-12     598
# 2012-12-13     655
# 2012-12-14     738
# 2012-12-15     335
# 2012-12-16     177
# 2012-12-17     236
# ...

# %%
fixed_df['Berri1'].plot()

# %%
fixed_df['Berri1'].plot(figsize=(15, 10))

# %%
fixed_df['Berri1'].plot.bar()

# %%
fixed_df['Berri1'].plot.area()

# %%
fixed_df['Berri1'].plot.line()

# %%
fixed_df.plot.scatter(x=1,y=5)

# %%
fixed_df.plot.hexbin(x=1,y=2, gridsize=15)
